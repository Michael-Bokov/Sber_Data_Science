# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-Bokov/Data_Science/blob/main/Transformers%3AGeneration(GPT_2)%26Translation(mGPT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Генерация текста  GPT-2
#
# ---

# %%
# !pip install torch==1.13.0
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 65.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 75.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.0 which is incompatible.
# ...

# %%
import os
import torch



if torch.cuda.is_available():
    device = "cuda"
    os.environ["CUDA_VISIBLE_DEVICES"] = "0"
    os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
else:
    device = "cpu"

print(device)
# Out:
# cuda

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel


# создадим инстанс GPT2Tokenizer, инициализировав его
# моделью gpt2-large с помощью метода from_pretrained
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')
# создадим инстанс GPT2LMHeadModel, инициализировав его
# моделью gpt2-large с помощью метода from_pretrained
model = GPT2LMHeadModel.from_pretrained('gpt2-large')
# сразу перенесем модель на девайс с помощью метода to
device="cpu"
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1280)
#     (wpe): Embedding(1024, 1280)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
# ...

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from transformers import pipeline


# Создаем pipeline обработки текста для задачи text-generation,
# который получает на вход модель, токенизатор и индекс доступного девайса
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device='cpu')

# %%
sentence = 'I want to buy this'
generated = pipe(sentence)
print(generated[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I want to buy this so I can eat out at the restaurant and have a nice meal with my food. There's something so good about this. I've only used it a few times, but I think I really like this sauce.

# %% [markdown]
# Перевод используя модель MGPT

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
# создадим инстанс GPT2Tokenizer, инициализировав его
# моделью sberbank-ai/mGPT с помощью метода from_pretrained
tokenizer = GPT2Tokenizer.from_pretrained('sberbank-ai/mGPT')
# создадим инстанс GPT2LMHeadModel, инициализировав его
# моделью sberbank-ai/mGPT с помощью метода from_pretrained
model = GPT2LMHeadModel.from_pretrained('sberbank-ai/mGPT')
# сразу перенесем модель на девайс с помощью метода to
device = "cpu"
model.to(device)
# Out:
# ...
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(100000, 2048)
#     (wpe): Embedding(2048, 2048)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
# ...

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device='cpu')

# %%
sentence = ''' \
Translate Русский to English: \

Русский: Сегодня отличный день, замечательный матч! Chinese: '''

generated = pipe(sentence, max_length=52)
print(generated[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  Translate Русский to English: \
#
# Русский: Сегодня отличный день, замечательный матч! Chinese: 今天很棒的日子,非常棒的比赛!
# English: Today is a great day, great match!
